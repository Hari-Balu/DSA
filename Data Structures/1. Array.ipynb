# %% [markdown]
# What is an Array in Python?
#
# An array is a collection of elements (values) stored at contiguous memory locations, all of the same data type (in most languages). In Python, the closest built-in equivalent is the list, but for strict data-type arrays, we use the array module or NumPy arrays.

# %% [markdown]
# ### Types of Arrays in Python

# %% [markdown]
# 1. List (Flexible, Mixed Types) – Most commonly used

# %%
arr = [10, 20, 30, 40]  # List in Python
print(arr[0])  # Access first element

# %% [markdown]
# 2. Array module (Fixed type)

# %%
import array

arr = array.array('i', [1, 2, 3, 4])  # 'i' = integer type
arr.append(5)
print(arr[2])  # Access third element

# %% [markdown]
# 3. NumPy arrays (For scientific computing)

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])
print(arr.mean())  # NumPy array supports advanced operations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Iterating Over an Array

# %%
arr = [10, 20, 30]
for x in arr:
    print(x)

# %% [markdown]
# Example: Sum of Elements in an Array

# %%
def array_sum(arr):
    total = 0
    for num in arr:
        total += num
    return total

print(array_sum([1, 2, 3, 4]))  # Output: 10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Exercise 1:
#
# Let us say your expense for every month are listed below,
#
# 1. January - 2200
# 2. February - 2350
# 3. March - 2600
# 4. April - 2130
# 5. May - 2190
#
# Create a list to store these monthly expenses and using that find out,
#
# 1. In Feb, how many dollars you spent extra compare to January?
# 2. Find out your total expense in first quarter (first three months) of the year.
# 3. Find out if you spent exactly 2000 dollars in any month
# 4. June month just finished and your expense is 1980 dollar. Add this item to our monthly expense list
# 5. You returned an item that you bought in a month of April and
# got a refund of 200$. Make a correction to your monthly expense list
# based on this

# %%
# Create an Array

exp = [2200,2350,2600,2130,2190]


# 1. In Feb, how many dollars you spent extra compare to January?

print("In feb this much extra was spent compared to jan:",exp[1]-exp[0])


# 2. Find out your total expense in first quarter (first three months) of the year

print("\nExpense for first quarter:",exp[0]+exp[1]+exp[2])


# 3. Find out if you spent exactly 2000 dollars in any month

print("\nDid I spent 2000$ in any month? ", 2000 in exp)


# 4. June month just finished and your expense is 1980 dollar. Add this item to our monthly expense list

exp.append(1980)
print("\nExpenses at the end of June:",exp)


# 5. You returned an item that you bought in a month of April and got a refund of 200$. Make a correction to your monthly expense list based on this

exp[3] = exp[3] - 200
print("\nExpenses after 200$ return in April:",exp)
# Out:
# In feb this much extra was spent compared to jan: 150
#
# Expense for first quarter: 7150
#
# Did I spent 2000$ in any month?  False
#
# Expenses at the end of June: [2200, 2350, 2600, 2130, 2190, 1980]
#
# Expenses after 200$ return in April: [2200, 2350, 2600, 1930, 2190, 1980]

# %% [markdown]
# ### Exercise 2:
#
# You have a list of your favourite marvel super heros.
#
# *   heros = ['spider man','thor','hulk','iron man','captain america']
#
# Using this find out,
#
# 1. Length of the list
# 2. Add 'black panther' at the end of this list
# 3. You realize that you need to add 'black panther' after 'hulk',
#    so remove it from the list first and then add it after 'hulk'
# 4. Now you don't like thor and hulk because they get angry easily :)
#    So you want to remove thor and hulk from list and replace them with doctor strange (because he is cool).
#    Do that with one line of code.
# 5. Sort the heros list in alphabetical order (Hint. Use dir() functions to list down all functions available in list)

# %%
# Take the List

heros = ['spider man','thor','hulk','iron man','captain america']

# 1. Length of the list

print("Length of the list:",len(heros))


# 2. Add 'black panther' at the end of this list

print("\nAdding black panther at the end:",heros.append('black panther'))


# 3. You realize that you need to add 'black panther' after 'hulk', so remove it from the list first and then add it after 'hulk'

heros.remove('black panther')
heros.insert(3,'black panther')
print("\nAdding black panther after hulk:",heros)


# 4. Now you don't like thor and hulk because they get angry easily :) So you want to remove thor and hulk from list and replace them with doctor strange (because he is cool). Do that with one line of code.

heros[1:3] = ['doctor strange']
print("\nReplacing thor and hulk with doctor strange:",heros)


# 5. Sort the heros list in alphabetical order (Hint. Use dir() functions to list down all functions available in list)

heros.sort()
print("\nSort the heros list in alphabetical order", heros)
# Out:
# Length of the list: 5
#
# Adding black panther at the end: None
#
# Adding black panther after hulk: ['spider man', 'thor', 'hulk', 'black panther', 'iron man', 'captain america']
#
# Replacing thor and hulk with doctor strange: ['spider man', 'doctor strange', 'black panther', 'iron man', 'captain america']
#
# Sort the heros list in alphabetical order ['black panther', 'captain america', 'doctor strange', 'iron man', 'spider man']

# %% [markdown]
# ### Exercise 3:
#
# Create a list of all odd numbers between 1 and a max number. Max number is something you need to take from a user using input() function.

# %%
# Create a List

max = int(input("Enter max number: "))

odd_numbers = []

for i in range(1, max):
    if i % 2 == 1:
        odd_numbers.append(i)

print("Odd numbers: ", odd_numbers)
