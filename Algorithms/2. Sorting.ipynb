# %% [markdown]
# What is Sorting?
#
# Sorting is the process of arranging elements in a specific order, typically ascending or descending.

# %% [markdown]
# Why is Sorting Important?
#
# 1. Makes searching faster (e.g., binary search requires sorted data)
# 2. Organizes data for reporting
# 3. Essential in many algorithms (e.g., greedy, divide & conquer)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Bubble Sort

# %% [markdown]
# What is Bubble Sort?
#
# Bubble Sort is a simple comparison-based sorting algorithm. It repeatedly swaps adjacent elements if they are in the wrong order, so that larger values "bubble" to the end of the list with each pass.

# %% [markdown]
# 🔁 How It Works (Intuition):
#
# For array [5, 1, 4, 2, 8]:
#
# Compare 5 and 1 → swap → [1, 5, 4, 2, 8]
#
# Compare 5 and 4 → swap → [1, 4, 5, 2, 8]
#
# Compare 5 and 2 → swap → [1, 4, 2, 5, 8]
#
# Compare 5 and 8 → no swap
#
# Repeat this for the remaining elements.

# %% [markdown]
# ✅ Python Code: Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        # Flag to check if any swap happened
        swapped = False
        for j in range(0, n - i - 1):  # Reduce comparisons each pass
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]  # Swap
                swapped = True
        if not swapped:
            break  # Array is already sorted
    return arr

# Example
arr = [64, 34, 25, 12, 22, 11, 90]
print(bubble_sort(arr))  # Output: [11, 12, 22, 25, 34, 64, 90]
# Out:
# [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Selection Sort

# %% [markdown]
# What is Selection Sort?
#
# Selection Sort is a simple comparison-based sorting algorithm. It works by repeatedly finding the minimum (or maximum) element from the unsorted part of the array and putting it in the correct position.

# %% [markdown]
# 🔁 How It Works
#
# For array [29, 10, 14, 37, 13]:
#
# Find the smallest element → 10
#
# Swap with the first → [10, 29, 14, 37, 13]
#
# Find the next smallest → 13
#
# Swap with second → [10, 13, 14, 37, 29]
#
# ...continue until sorted

# %% [markdown]
# ✅ Python Code: Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        # Find index of the smallest element in the remaining array
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        # Swap the found minimum with the first element
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

# Example
arr = [29, 10, 14, 37, 13]
print(selection_sort(arr))  # Output: [10, 13, 14, 29, 37]
# Out:
# [10, 13, 14, 29, 37]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Insertion Sort

# %% [markdown]
# What is Insertion Sort?
#
# Insertion Sort is a simple, intuitive sorting algorithm that builds the final sorted array one element at a time by inserting each element into its correct position among the previously sorted elements.

# %% [markdown]
# 🔁 How It Works
#
# For array [8, 5, 2, 9]:
#
# Start with second element (5)
#
# Compare it with previous elements and insert it in correct position
#
# Repeat for all elements
#
# Intermediate steps:
#
# [5, 8, 2, 9]
#
# [2, 5, 8, 9] → Sorted

# %% [markdown]
# ✅ Python Code: Insertion Sort

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        # Move elements greater than key to one position ahead
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key  # Insert key in correct position
    return arr

# Example
arr = [8, 5, 2, 9, 1]
print(insertion_sort(arr))  # Output: [1, 2, 5, 8, 9]
# Out:
# [1, 2, 5, 8, 9]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Merge Sort

# %% [markdown]
# What is MergeSort?
#
# MergeSort is a classic Divide and Conquer sorting algorithm. It works by:
#
# 1. Dividing the array into halves,
# 2. Sorting each half recursively,
# 3. Merging the sorted halves back together.

# %% [markdown]
# 🧠 Key Idea
#
# 1. Break the array until each piece has 1 element.
# 2. Merge sorted pieces step-by-step.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ✅ Python Code: Merge Sort

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr  # Base case: already sorted

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])    # Sort left half
    right = merge_sort(arr[mid:])   # Sort right half

    return merge(left, right)       # Merge sorted halves

def merge(left, right):
    result = []
    i = j = 0

    # Compare elements from both halves and merge
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:  # Stable sort: maintains original order
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    # Add remaining elements
    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Example
arr = [6, 3, 8, 5, 2, 7, 4, 1]
sorted_arr = merge_sort(arr)
print(sorted_arr)  # Output: [1, 2, 3, 4, 5, 6, 7, 8]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# 🔁 How It Works (Example: [4, 2, 1, 3]):
#
# Divide:
#
# → [4, 2] and [1, 3]
#
# → [4], [2], [1], [3]
#
# Merge:
#
# → [2, 4], [1, 3]
#
# → [1, 2, 3, 4]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Quick Sort

# %% [markdown]
# What is QuickSort?
#
# QuickSort is a highly efficient divide-and-conquer sorting algorithm. It works by selecting a pivot element and partitioning the array such that:
#
# 1. Elements less than pivot go to the left
# 2. Elements greater than pivot go to the right
# 3. It then recursively sorts the left and right parts.

# %% [markdown]
# 🧠 Key Concepts
#
# 1. Pivot: Element used to divide the array (can be first, last, random, or median)
# 2. Partitioning: Rearranging elements based on pivot
# 3. Recursive calls: Applied on subarrays

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ✅ Python Code: Quick Sort

# %%
def quicksort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)  # Partition index
        quicksort(arr, low, pi - 1)     # Left subarray
        quicksort(arr, pi + 1, high)    # Right subarray

def partition(arr, low, high):
    pivot = arr[high]  # Choose last element as pivot
    i = low - 1        # Index of smaller element

    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]  # Swap smaller element forward

    arr[i + 1], arr[high] = arr[high], arr[i + 1]  # Swap pivot to correct place
    return i + 1

# Example
arr = [10, 7, 8, 9, 1, 5]
quicksort(arr, 0, len(arr) - 1)
print(arr)  # Output: [1, 5, 7, 8, 9, 10]
# Out:
# [1, 5, 7, 8, 9, 10]

# %% [markdown]
# How It Works (Step-by-Step for [10, 7, 8, 9, 1, 5]):
#
# 1. Pick pivot (5)
#
# 2. Rearrange so values < 5 left, > 5 right
#
# 3. Recursively apply to both sides
#
# 4. Combine the sorted subarrays

# %% [markdown]
# ![image.png](data:image/png;base64,...)
