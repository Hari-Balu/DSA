# %% [markdown]
# What is the Two Pointer Technique?
#
# The Two Pointer technique uses two variables (pointers) to traverse a data structure — usually a list or array — to optimize algorithms, especially when dealing with sorted arrays or problems involving pairs, windows, or subarrays.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 1: Find if a Pair Exists With Given Sum (Sorted Array)

# %%
def has_pair_with_sum(arr, target):
    left, right = 0, len(arr) - 1
    while left < right:
        current_sum = arr[left] + arr[right]
        if current_sum == target:
            return True
        elif current_sum < target:
            left += 1
        else:
            right -= 1
    return False

print(has_pair_with_sum([1, 2, 3, 4, 6], 7))  # Output: True (1+6 or 3+4)
# Out:
# True

# %% [markdown]
# Example 2: Reverse an Array Using Two Pointers

# %%
def reverse_array(arr):
    left, right = 0, len(arr) - 1
    while left < right:
        arr[left], arr[right] = arr[right], arr[left]
        left += 1
        right -= 1
    return arr

print(reverse_array([1, 2, 3, 4, 5]))  # Output: [5, 4, 3, 2, 1]
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Example 3: Check if a String is a Palindrome

# %%
def is_palindrome(s):
    left, right = 0, len(s) - 1
    while left < right:
        if s[left] != s[right]:
            return False
        left += 1
        right -= 1
    return True

print(is_palindrome("madam"))  # Output: True
# Out:
# True

# %% [markdown]
# 💡 Why Two Pointers?
#
# ✅ More efficient than nested loops (O(n) vs O(n²))
#
# ✅ Often used in sorted arrays or problems with constraints on distance, sum, or subarray length
#
# ✅ Frequently appears in interview questions
