# %% [markdown]
# What is Searching?
#
# Searching is the process of finding the location or presence of an element in a collection like an array, list, or dataset.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Linear Search (Brute Force)

# %% [markdown]
# 🔸 Description:
#
# 1. Checks each element one by one.
#
# 2. Works on unsorted data.

# %% [markdown]
# Example:

# %%
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

print(linear_search([10, 20, 30, 40], 30))  # Output: 2
# Out:
# 2

# %% [markdown]
# # 2. Binary Search (Efficient)

# %% [markdown]
# 🔸 Description:
#
# 1. Works only on sorted data
# 2. Repeatedly divides the array in half.

# %% [markdown]
# Example:

# %%
def binary_search(arr, target):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1


print(binary_search([10, 20, 30, 40, 50], 30))  # Output: 2
# Out:
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)
