# %% [markdown]
# What is Big O Notation?
#
# Big O notation is a way to describe the time or space complexity of an algorithm in terms of input size (n). It helps you understand how your code performs as the input grows large - especially in the worst-case scenario.

# %% [markdown]
# Why Big O Matters?
#
# ✅ Helps compare algorithm efficiency
#
# ✅ Critical in choosing the right data structure or algorithm
#
# ✅ Important in interviews, competitive programming, and real-world scaling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1. Constant Time - O(1)

# %%
def get_first_item(lst):
    return lst[0]

# %% [markdown]
# ### 2. Linear Time - O(n)

# %%
def print_all_items(lst):
    for item in lst:
        print(item)

# %% [markdown]
# ### 3. Quadratic Time - O(n²)

# %%
def print_pairs(lst):
    for i in lst:
        for j in lst:
            print(i, j)

# %% [markdown]
# ### 4. Logarithmic - O(log n)

# %%
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid  # Target found
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1

    return -1  # Target not found

# %% [markdown]
# ### 5. Log linear - O(n log n)

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(left, right):
    merged = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            merged.append(left[i])
            i += 1
        else:
            merged.append(right[j])
            j += 1

    merged += left[i:]
    merged += right[j:]
    return merged

# %% [markdown]
# ### 6. Exponential - O(2ⁿ)

# %%
def fib(n):
    if n <= 1:
        return n
    return fib(n - 1) + fib(n - 2)

# %% [markdown]
# ### 7. Factorial - O(n!)

# %%
from itertools import permutations

def tsp_brute_force(graph):
    n = len(graph)
    min_cost = float('inf')
    for perm in permutations(range(n)):
        cost = 0
        for i in range(n):
            cost += graph[perm[i]][perm[(i+1)%n]]
        min_cost = min(min_cost, cost)
    return min_cost

# %% [markdown]
# ### 📦 Space Complexity
# Big O is also used to describe memory usage:

# %%
def create_list(n):
    return [0] * n   # O(n) space

# %% [markdown]
# ### 📘 Quick Tip: Drop Constants and Lower Order Terms
#
# *   O(2n + 10) → O(n)
# *   O(n² + n) → O(n²)
